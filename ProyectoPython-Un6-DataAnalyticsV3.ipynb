# %%
# PROYECTO PYTHON - UNIDAD 6 - DATA ANALYTICS V3

# %%
# 1. 
# Escribe una función que reciba una cadena de texto como parámetro y 
# devuelva un diccionario con las frecuencias de cada letra en la cadena. 
# Los espacios no deben ser considerados    

def contador_de_frecuencia (texto):
    """Función que recibe una cadena de texto y devuelve un diccionario con las frecuencias de cada letra en la cadena.
     
      Los espacios no son considerados.

    Args
        texto (str): cadena de texto a analizar

    Returns:
        frecuencias (dict): diccionario con las frecuencias de cada letra en la cadena
    """
    # Creamos el diccionario con las frecuencias de cada letra en la cadena.

    frecuencias = {}

    # Recorremos letra por letra la cadena de texto. 

    for letra in texto:

        if letra != " ":

            #Utilizo al función .get, que devuelve el valor actual, o 0 en caso que no exista.

            frecuencias[letra]= frecuencias.get(letra,0) + 1

    return frecuencias


texto_ej_1 = "Un día como cualquier otro"

resultado_ej_1 = contador_de_frecuencia (texto_ej_1)

print (resultado_ej_1)
# Out:
# {'U': 1, 'n': 1, 'd': 1, 'í': 1, 'a': 2, 'c': 2, 'o': 4, 'm': 1, 'u': 2, 'l': 1, 'q': 1, 'i': 1, 'e': 1, 'r': 2, 't': 1}

# %%
# 2.
# Dada una lista de números, obtén una nueva lista con el doble de cada valor.
# Usa la función map()

lista=[35,49,38,2,4,1,56,29]

def doblenum (num):
    """Función que recibe un número y devuelve el doble de ese número.
    """
    
    return num*2

lista_doble=list(map(doblenum,lista))

print(lista_doble)
# Out:
# [70, 98, 76, 4, 8, 2, 112, 58]

# %%
# 3.
# Escribe una función que tome una lista de palabras y una palabra objetivo
# como parámetros. La función debe devolver una lista con todas las palabras
# de la lista original que contengan la palabra objetivo


def filtro_palabras (lista_3,palabraobjetivo):
    """Función que recibe una lista de palabras y una palabra objetivo, 
    y devuelve una lista con todas las palabras de la lista original que contengan la palabra objetivo.


    Args:
        lista_3 (list): lista de palabras a filtrar
        palabraobjetivo (str): palabra objetivo para buscar

    Returns:
        lista_resultado_3 (list): lista con las palabras que contienen la palabra objetivo
    """
    lista_resultado_3=[]

    for palabra in lista_3:

        if palabraobjetivo in palabra:

            lista_resultado_3.append(palabra)

    return lista_resultado_3




lista_palabra_ej_3 =['demagogia', 'demografia', 'museo', 'duende', 'provincia', 'rodete']

filtro_palabras(lista_palabra_ej_3,"de")
# Out:
# ['demagogia', 'demografia', 'duende', 'rodete']

# %%
# 4.
# Genera una función que calcule la diferencia entre los valores de dos listas. 
# Usa la función map()


lista1= [12,15,27]
lista2= [10,8,45]

def restalistas (num):
    """Función que resta valores de dos listas en posiciones correspondientes.

    Calcula la diferencia entre un elemento de lista2 y su correspondiente en lista1.

    Args:
        num (int o float): número de lista2 para restar

    Returns:
        int o float: diferencia entre elementos de lista1 y lista2"""

    indice = lista2.index(num)

    return lista1[indice]-num

resultado_map=map(restalistas,lista2)

lista_resta=list(resultado_map)

print(lista_resta)
# Out:
# [2, 7, -18]

# %%
# 5.
# Escribe una función que tome una lista de números como parámetro y 
# un valor opcional nota_aprobado, que pordefecto es 5. 
# La función debe calcular la media de los números en la lista y 
# determinar si la media es mayor o igual que nota aprobado. 
# Si es así, el estado será "aprobado", de lo contrario, será "suspenso". 
# La función debe devolver una tupla que contenga la media y el estado.

from functools import reduce

def situacion_nota (lista,media=5):
    """Función que calcula la media de una lista y determina si está aprobada.

    Calcula el promedio de una lista de números y determina si alcanza la nota mínima.

    Args:
        lista (list): lista de números
        media (int, optional): nota mínima para aprobar. Defaults to 5.

    Returns:
        tupla_situacion: tupla con el estado (Aprobado/Suspendido) y el promedio"""
    
    promedio = reduce(lambda a,b: a+b, lista)/len(lista)

    if promedio > media:
            
        Estado = "Aprobado"
        print (f"Estado {Estado}")

    else:
           Estado= "Suspendido"
           print (f"Estado Suspendido")

    tupla_situacion=(Estado,promedio)
    
    return tupla_situacion

# %%
# 6.
# . Escribe una función que calcule el factorial de un número de manera recursiva.

def factorial(numero):
    """
    Esta función realiza el factorial del número especificado como argumento.

    Args:
        numero (int): número del cual se desea calcular el factorial

    Returns:
        Factorial del numero indicado
    """
    
    # Establecemos los casos particulares de factoriales de cero y uno
    
    if numero == 0 or numero == 1:

        return 1

    else:

    # Establecemos la condición para continuar la sucesión de factoriales

        return numero * factorial(numero-1)

# %%
# Ejemplo de uso de la función factorial del enunciado 6
numero= 4
resultado=factorial(numero)
print(resultado)
# Out:
# 24

# %%
# 7. 
#  Genera una función que convierta una lista de tuplas a una lista de strings. 
#  Usa la función map()

lista_tuplas=[(32,'Pedro'),(True,),('Juan',45)]
lista_str1=[]

for tupla in lista_tuplas:
    for elemento in tupla:
        elemento_str=str(elemento)
        lista_str1.append(elemento_str)

print(lista_str1)        



lista_str2=[]

def conv_str (lista_tupla):   
    
    return list(map(str,lista_tupla))


lista_str2 = conv_str(lista_tuplas)

print(lista_str2)
# Out:
# ['32', 'Pedro', 'True', 'Juan', '45']
# ["(32, 'Pedro')", '(True,)', "('Juan', 45)"]

# %%
# 8.
# Escribe un programa que pida al usuario dos números e intente dividirlos. 
# Si el usuario ingresa un valor no numérico o intenta dividir por cero, maneja esas excepciones de manera 
# adecuada. Asegúrate de mostrar un mensaje indicando si la división fue exitosa o no.




def division_input(num1,num2):
    """Función que divide dos números.

    Realiza la operación de división entre dos números ingresados.

    Args:
        num1 (float): dividendo
        num2 (float): divisor (no puede ser cero)

    Returns:
        float: resultado de la división"""
    
    return num1/num2

try:
    a= float(input ("Por favor ingrese el número a ser dividido"))
    b= float(input ("Por favor ingresar un número que será el divisor"))

    result_division= division_input(a,b)

except ZeroDivisionError:
    print(f"No se puede dividir por {b}")

except ValueError:
    print(f"Por favor ingresar números válidos")    

else:
    print(f"La operación fue exitosa. El resultado de la división es {result_division}")
# Out:
# La operación fue exitosa. El resultado de la división es 0.8888888888888888

# %%
# 9. Escribe una función que tome una lista de nombres de mascotas como parámetro y devuelva una nueva lista
# excluyendo ciertas mascotas prohibidas en España. La lista de mascotas a excluir es ["Mapache", "Tigre",
# "Serpiente Pitón", "Cocodrilo", "Oso"].Usa la función filter()

def mascostas_permitidas(lista_mascotas):              ###HACER!!!!

    """Función que filtra mascotas permitidas en España.

    Elimina de la lista las mascotas prohibidas.

    Args:
        lista_mascotas (list): lista de nombres de mascotas

    Returns:
        list: lista de mascotas permitidas (sin las prohibidas)"""

    mascotas_prohibidas = ['mapache','tigre', 'serpiente pitón', 'cocodrilo', 'oso']

    mascotas_filtro = filter(lambda mascota: mascota.lower() not in mascotas_prohibidas, lista_mascotas)

    return list(mascotas_filtro)



milista_animales = ["perro","gato","tucan","Oso","Leon","Tigre"]

try:
   mis_mascotas_permitidas = mascostas_permitidas(milista_animales)
   
except AttributeError:
    print("Agregar elementos a la lista")

else:
    print(mis_mascotas_permitidas)
# Out:
# ['perro', 'gato', 'tucan', 'Leon']

# %%
# 10. Ecribe una función que reciba una lista de números y calcule su promedio. Si la lista está vacía, lanza una
# Excepción personalizada y maneja el error adecuadamente

def calcular_promedio (listanumeros):
    
    """Función que calcula el promedio de una lista de números.

    Suma todos los elementos y divide entre la cantidad de elementos.
    Lanza ZeroDivisionError si la lista está vacía.

    Args:
        listanumeros (list): lista de números para promediar

    Returns:
        float: promedio de los números en la lista"""
 
    sumaelementos= sum(listanumeros)
    promedio= sumaelementos / len(listanumeros)

    return promedio

milista_de_numeros=[]

try:
    promedioejercicio = calcular_promedio(milista_de_numeros)

except ZeroDivisionError:
    print ("Revisar la lista de números")    

else:
    print (f"El promedio de la lista de números es: {promedioejercicio}")
# Out:
# Revisar la lista de números

# %%
# 11.
# Escribe un programa que pida al usuario que introduzca su edad. 
# Si el usuario ingresa un valor no numérico o un valor fuera del rango esperado 
# (por ejemplo, menor que 0 o mayor que 120), maneja las excepciones adecuadamente.

def solicitar_edad():
    
    """Función que solicita y valida la edad de un usuario.

    Pide al usuario que ingrese su edad y verifica que esté en rango válido (0-120).
    Maneja excepciones si el input no es un número válido."""

    edad_entrada = input ("Por favor ingrese su edad")

    edad = int (edad_entrada)
    
    if 0 <= edad <= 120:
        print(f"La edad ingresada es: {edad}")

    else:
        print("Por favor ingrese una edad entre 0 y 120")    

try:
    solicitar_edad ()

except ValueError:
    print("Por favor ingrese un valor válido")
# Out:
# Por favor ingrese una edad entre 0 y 120

# %%
# 12. 
# Genera una función que al recibir una frase devuelva una lista con la longitud de cada palabra. 
# Usa la función map()

frase_12="La vida es bella"

def longitud_palabras(frase):
    """Función que calcula la longitud de cada palabra en una frase.

    Separa la frase en palabras y devuelve una lista con la longitud de cada palabra.

    Args:
        frase (str): frase a analizar

    Returns:
        list: lista con la longitud de cada palabra"""
    
    palabras = frase.split()
    longitudes = list(map(len, palabras))
    
    return longitudes

print(longitud_palabras(frase_12))
# Out:
# [2, 4, 2, 5]

# %%
# 13.
# Genera una función la cual, para un conjunto de caracteres, devuelva una lista de tuplas con cada letra 
# en mayúsculas y minúsculas. Las letras no pueden estar repetidas .Usa la función map()

conj_caract_entrada = "dnsao sad"

def generar_tuplas(cadenacaracteres):
        
    """Función que genera tuplas con versiones mayúsculas y minúsculas de caracteres.

    Toma una cadena, elimina espacios, obtiene caracteres únicos y los convierte
    en tuplas de (mayúscula, minúscula).

    Args:
        cadenacaracteres (str): cadena de caracteres de entrada

    Returns:
        list: lista de tuplas (carácter_mayúscula, carácter_minúscula)"""

    cadenacaracteres = list(cadenacaracteres.replace(" ",""))

    caracteresunicos = set(cadenacaracteres)

    lista_resultado_13 = list (map (lambda c : (c.upper(), c.lower()), caracteresunicos))
                               
    return lista_resultado_13



entrada_caracteres = "asoas  fwifsdf aoas"

lista_cuplas_may_min = generar_tuplas(entrada_caracteres)

print(lista_cuplas_may_min)
# Out:
# [('W', 'w'), ('I', 'i'), ('A', 'a'), ('F', 'f'), ('D', 'd'), ('S', 's'), ('O', 'o')]

# %%
# 14.
# Crea una función que retorne las palabras de una lista de palabras que comience con una letra en especifico.
# Usa la función filter()

def palabra_con_c (palabra):
        
    """Función que verifica si una palabra comienza con la letra "c".

    Args:
        palabra (str): palabra a verificar

    Returns:
        bool: True si la palabra comienza con "c", False en caso contrario"""        
    
    return palabra[0].lower() == "c"


lista_palabras_14 = ['Taza', 'Casa', 'Cielo', 'Bicicleta', 'Silla', 'color']
palabras_con_c = list(filter(palabra_con_c, lista_palabras_14))

print(palabras_con_c)
# Out:
# ['Casa', 'Cielo', 'color']

# %%
# 15
# Crea una función lambda que sume 3 a cada número de una lista dada.

lista_numeros_15 = [2,7,5,8]

mas_3 = list(map(lambda x: x+3, lista_numeros_15))

print(mas_3)
# Out:
# [5, 10, 8, 11]

# %%
# 16
# Escribe una función que tome una cadena de texto y un número entero n como parámetros y devuelva una lista 
# de todas las palabras que sean más largas que n. Usa la función filter()


def palabras_largas_n (cadenatexto,n):

    """Función que filtra palabras más largas que n caracteres.

    Divide un texto en palabras y retorna solo aquellas que superan la longitud n.

    Args:
        cadenatexto (str): texto a procesar
        n (int): longitud mínima de las palabras

    Returns:
        list: lista de palabras más largas que n caracteres"""
    
    listapalabras = cadenatexto.split()

    
    palabras_mas_de_n_caracteres = list(filter(lambda palabra: len(palabra) > n,listapalabras))
    
    
    return palabras_mas_de_n_caracteres



frase="la vida es bella"

lista_resultado_16 = palabras_largas_n (frase,3)

print(lista_resultado_16)
# Out:
# ['vida', 'bella']

# %%
# 17.
#crea una función que tome una lista de dígitos y devuelva el número correspondiente. 
# Por ejemplo, [5,7,2]corresponde al número quinientos setenta y dos (572). Usa la función reduce()


lista_digitos = [3,8,0,1,9,2,5]
numero_resultado= int(reduce(lambda x,y: str(x)+str(y),lista_digitos))

print(numero_resultado)
# Out:
# 3801925

# %%
# 18.
# Escribe un programa en Python que cree una lista de diccionarios que contenga información de estudiantes
#(nombre, edad, calificación) y use la función filter para extraer a los estudiantes con una calificación
#  mayor o igual a 90. Usa la función filter()

lista_estudiantes = [
    {"nombre": "Juan", "edad": 23, "calificación": 78},
    {"nombre": "Daniel", "edad": 19, "calificación": 93},
    {"nombre": "Lara", "edad": 21, "calificación": 98 },
    {"nombre": "Sergio", "edad": 18, "calificación": 80 },
    {"nombre": "Romina", "edad": 20, "calificación": 100},
    {"nombre": "Carlos", "edad": 22 , "calificación": 88},
    {"nombre": "Luis", "edad": 21, "calificación": 75}
]


lista_estudiantes_calif_90 = list(filter(lambda e: e["calificación"] >= 90, lista_estudiantes))

for estudiante in lista_estudiantes_calif_90:
    print (estudiante)
# Out:
# {'nombre': 'Daniel', 'edad': 19, 'calificación': 93}
# {'nombre': 'Lara', 'edad': 21, 'calificación': 98}
# {'nombre': 'Romina', 'edad': 20, 'calificación': 100}

# %%
# 19. 
# Crea una función lambda que filtre los números impares de una lista dada

lista_numeros_19 = [2,17,45,34,92]

lista_impares_19 = list(filter(lambda x: x % 2 != 0, lista_numeros_19))

print(lista_impares_19)
# Out:
# [17, 45]

# %%
# 20.
# Para una lista con elementos tipo integer y string obtén una nueva lista sólo con los valores int. 
# Usa la función filter()

lista_elementos_20 = ['Juan', 'Dirección', 202, 45, 'España']

lista_enteros_20 = list(filter(lambda elemento: type(elemento) is int , lista_elementos_20 ))

print(lista_enteros_20)



numero= 2

print (type(numero))
# Out:
# [202, 45]
# <class 'int'>

# %%
# 21.
# Crea una función que calcule el cubo de un número dado mediante una función lambd


cubo_numero = lambda x: x**3

#------------------

numero_dado_21 = 4

resultado_cubo = cubo_numero(numero_dado_21)

print(resultado_cubo)
# Out:
# 64

# %%
# 22.
# Dada una lista numérica, obtén el producto total de los valores de dicha lista.
# Usa la función reduce()


lista_numeros_22 =[2,4,6,5,2,8,5]

resultado_22 = reduce(lambda x,y: x*y, lista_numeros_22)

print(resultado_22)
# Out:
# 19200

# %%
# 23. 
# Concatena una lista de palabras.
# Usa la función reduce()

lista_palabras_23 = ['Hola', 'me', 'llamo', 'Juan']

cadena_resultado_23 = reduce(lambda x,y: x+" "+y, lista_palabras_23)

print(cadena_resultado_23)
# Out:
# Hola me llamo Juan

# %%
# 24.
# Calcula la diferencia total en los valores de una lista. 
# Usa la función reduce()


lista_numeros_24 = [10,8,5,15,23,9]

diferencia_total_24 = reduce(lambda x,y: x-y, lista_numeros_24)

print (diferencia_total_24)
# Out:
# -50

# %%
# 25.
# Crea una función que cuente el número de caracteres en una cadena de texto dada


contar_caracteres = lambda x: len(x)

frase="Buenos días, probando función"

cant_caracteres_25 = contar_caracteres(frase)

print(cant_caracteres_25)
# Out:
# 29

# %%
# 26.
# Crea una función lambda que calcule el resto de la división entre dos números dados

resto_division = lambda a,b: a % b

resultado_resto = resto_division (10,8)


print(resultado_resto)
# Out:
# 2

# %%
# 27. 
# Crea una función que calcule el promedio de una lista de números.

lista_numeros_27 = [10,15,20,25]

promedio_lista_27 = reduce(lambda x,y: x+y, lista_numeros_27)/len(lista_numeros_27)

print(promedio_lista_27)
# Out:
# 17.5

# %%
# 28. 
# Crea una función que busque y devuelva el primer elemento duplicado en una lista dada

def encontrar_primer_elemento_duplicado (lista):

    """Función que encuentra el primer elemento duplicado en una lista.

    Itera sobre la lista y devuelve el primer elemento que aparece dos veces.
    Si no hay duplicados, devuelve None.

    Args:
        lista (list): lista de elementos

    Returns:
        elemento or None: primer elemento duplicado o None si no hay duplicados"""
    
    elementos_chequeados = set()

    for elemento in lista:
        if elemento in elementos_chequeados:
            return elemento
        else:
            elementos_chequeados.add(elemento)

    return None
        

lista_a_revisar=[14,2,87,45,22,2,14,95,87]

primer_elemento_rep = encontrar_primer_elemento_duplicado(lista_a_revisar)


print(primer_elemento_rep)
# Out:
# 2

# %%
# 29.
# Crea una función que convierta una variable en una cadena de texto y enmascare todos los caracteres con el
#carácter '#', excepto los últimos cuatro


def funcion_enmascarar(variable):
    
    """Función que enmasca caracteres en una cadena, dejando solo los últimos 4.

    Reemplaza todos los caracteres con "#" excepto los últimos 4 dígitos o caracteres.

    Args:
        variable (any): variable a enmascarar (se convierte a string)

    Returns:
        str: cadena enmascarada o cadena original si tiene ≤4 caracteres"""

    cadena_texto = str(variable)

    if len(cadena_texto) <= 4:
        
        return cadena_texto

    else:
        return "#" * (len(cadena_texto)-4) + cadena_texto [-4:] 


cadena_ej_29 = "Bienvenidos a todos"

resultado_ej_29 = funcion_enmascarar(cadena_ej_29)

print (resultado_ej_29)
# Out:
# ###############odos

# %%
# 30.
# . Crea una función que determine si dos palabras son anagramas, es decir, si están formadas por las mismas letras
# pero en diferente orden

def palabrasiguales (palabra1,palabra2):
    
    """Función que determina si dos palabras son anagramas.

    Compara los conjuntos de caracteres de ambas palabras para verificar si son anagramas.

    Args:
        palabra1 (str): primera palabra
        palabra2 (str): segunda palabra"""

    set1=set(palabra1)
    set2=set(palabra2)

    if set1 ==set2:
        return print(f"{palabra1} y {palabra2} son anagramas")
    else:
        return print(f"{palabra1} y {palabra2} no son anagramas")
    
palabra_ej_30_1 = 'asd'

palabra_ej_30_2='dsa'

palabrasiguales(palabra_ej_30_1,palabra_ej_30_2)
# Out:
# asd y dsa son anagramas

# %%
# 31.
# Crea una función que solicite al usuario ingresar una lista de nombres y luego solicite un nombre para buscar en
# esa lista. Si el nombre está en la lista, se imprime un mensaje indicando que fue encontrado, de lo contrario, se
# lanza una excepción.


def buscar_nombres():
    
    """Función que busca un nombre en una lista ingresada por el usuario.

    Solicita al usuario ingresar una lista de nombres y luego busca un nombre específico
    en esa lista (case-insensitive)."""
    
    entrada_nombres = input ("Ingresa una lista de nombres separados por comas:")

    # Transformar el input del usuario en lista, llevando todo a minúsculas y eliminando espacios en blanco

    lista_nombres = [nombre.strip().lower() for nombre in entrada_nombres.split(",")]

    # Solicitar al usuario el nombre a buscar, llevar lo ingresado a minúsculas y eliminar espacios en blanco

    nombre_a_buscar = input ("Ingrese el nombre a buscar en la lista:").strip().lower()

    
    if nombre_a_buscar in lista_nombres:
        print("Se ha encontrado el nombre en la lista")

    else:
        print(f"El nombre no ha sido encontrado en la lista de nombres")

    


buscar_nombres()
# Out:
# Se ha encontrado el nombre en la lista

# %%
# 32.
# Crea una función que tome un nombre completo y una lista de empleados, busque el nombre completo en la lista y
# devuelve el puesto del empleado si está en la lista, de lo contrario, devuelve un mensaje indicando que la 
# persona no trabaja aquí


def obtener_puesto_de_trabajo (nombre_completo, lista_empleados):
    
    """Función que obtiene el puesto de un empleado buscando por nombre.

    Busca un empleado por nombre en una lista de diccionarios y devuelve su puesto.

    Args:
        nombre_completo (str): nombre del empleado a buscar
        lista_empleados (list): lista de diccionarios con datos de empleados

    Returns:
        str: puesto del empleado o mensaje si no se encuentra"""
    
    for empleado in lista_empleados:

        if empleado.get("nombre").lower() == nombre_completo.lower():

            return empleado.get("puesto")
            
        

    return "No se ha encontrado el empleado en nuestra lista"
        

lista_empleados_32 = [
        {"nombre": "Ana", "edad": 25 , "puesto": "Administración",  "salario": 18000},
        {"nombre": "Pedro", "edad": 44 , "puesto": "Limpieza",  "salario":16000 },
        {"nombre": "Rocio", "edad": 32 , "puesto": "Sistemas",  "salario": 22000},
        {"nombre": "Ramona", "edad": 26 , "puesto": "Gerencia",  "salario": 28000},
        {"nombre": "Eladio", "edad": 55 , "puesto": "Controller",  "salario": 24000},
        {"nombre": "Alex", "edad": 62 , "puesto": "Vendedor",  "salario":25000 },
        {"nombre": "Claudia", "edad": 46 , "puesto": "Finanzas",  "salario": 24000},
]

nombre_completo_32 = "Alex"

resultado_ej_32 = obtener_puesto_de_trabajo(nombre_completo_32, lista_empleados_32)

print (resultado_ej_32)
# Out:
# Vendedor

# %%
# 33.
# Crea una función lambda que sume elementos correspondientes de dos listas dadas.



# Utilizamos la función zip, que junta los elementos de dos listas en forma de tuplas


sumar_elementos_listas = lambda lista1, lista2: [x+y for x,y in zip(lista1, lista2)]


# Revisamos un ejemplo para chequear su funcionamiento

lista_ej33_1=[5,2,7,3]
lista_ej33_2 = [3,1,3,6]

lista_resultado_33 = sumar_elementos_listas(lista_ej33_1, lista_ej33_2)

print(lista_resultado_33)



print(list(zip(lista_ej33_1, lista_ej33_2)))
# Out:
# [8, 3, 10, 9]
# [(5, 3), (2, 1), (7, 3), (3, 6)]

# %%
# 34. 
# Crea la clase Arbol , define un árbol genérico con un tronco y ramas como atributos. Los métodos disponibles son: 
# crecer_tronco , nueva_rama , crecer_ramas , quitar_rama e info_arbol . El objetivo es implementar estos métodos para
# manipular la estructura del árbol.
#Código a seguir:
#1. Inicializar un árbol con un tronco de longitud 1 y una lista vacía de ramas.
#2. Implementar el método crecer_tronco para aumentar la longitud del tronco en una unidad.
#3. Implementar el método nueva_rama para agregar una nueva rama de longitud 1 a la lista de ramas.
#4. Implementar el método crecer_ramas para aumentar en una unidad la longitud de todas las ramas existentes.
#5. Implementar el método quitar_rama para eliminar una rama en una posición específica.
#6. Implementar el método info_arbol para devolver información sobre la longitud del tronco, el número de ramas y las longitudes de las mismas.
#Caso de uso:
#1. Crear un árbol.
#2. Hacer crecer el tronco del árbol una unidad.
#3. Añadir una nueva rama al árbol.
#4. Hacer crecer todas las ramas del árbol una unidad.
#5. Añadir dos nuevas ramas al árbol.
#6. Retirar la rama situada en la posición 2.
#7. Obtener información sobre el árbol.

class Arbol:
    def __init__(self):
        self.tronco = 1
        self.ramas = []

    def crecer_tronco(self):
        self.tronco += 1

    def nueva_rama(self):
        self.ramas.append(1)

    def crecer_ramas(self):
        self.ramas = [rama + 1 for rama in self.ramas]

    def quitar_rama(self, posicion):
        if 0 <= posicion < len(self.ramas):
            del self.ramas[posicion]

    def info_arbol(self):
        return {
            "longitud_tronco": self.tronco,
            "numero_ramas": len(self.ramas),
            "longitudes_ramas": self.ramas
        }

# %%
# 35. No hay enunciado 35

# %%
# 36.
# Crea la clase UsuarioBanco ,representa a un usuario de un banco con su nombre, saldo y si tiene o no cuenta
# corriente. Proporciona métodos para realizar operaciones como retirar dinero, transferir dinero desde otro usuario y
# agregar dinero al saldo.
# Código a seguir:
#1. Inicializar un usuario con su nombre, saldo y si tiene o no cuenta corriente mediante True y False .
#2. Implementar el método retirar_dinero para retirar dinero del saldo del usuario. Lanzará un error en caso de no poder hacerse.
#3. Implementar el método transferir_dinero para realizar una transferencia desde otro usuario al usuario actual.Lanzará un error en caso de no poder hacerse.
#4. Implementar el método agregar_dinero para agregar dinero al saldo del usuario.
#Caso de uso:
#1. Crear dos usuarios: "Alicia" con saldo inicial de 100 y "Bob" con saldo inicial de 50, ambos con cuenta corriente.
#PROYECTO LÓGICA: Katas de Python 3
#2. Agregar 20 unidades de saldo de "Bob".
#3. Hacer una transferencia de 80 unidades desde "Bob" a "Alicia".
#4. Retirar 50 unidades de saldo a "Alicia"


class UsuarioBanco:
    """Clase que representa a un usuario de un banco.

    Atributos:
        nombre (str): nombre del usuario
        saldo (float): saldo actual del usuario
        cuenta_corriente (bool): indica si el usuario tiene cuenta corriente

    Métodos:
        retirar_dinero(cantidad): retira dinero del saldo del usuario
        transferir_dinero(otro_usuario, cantidad): transfiere dinero desde otro usuario al usuario actual
        agregar_dinero(cantidad): agrega dinero al saldo del usuario
    """
    
    def __init__(self, nombre, saldo, cuenta_corriente):
        self.nombre = nombre
        self.saldo = saldo
        self.cuenta_corriente = cuenta_corriente

    def retirar_dinero(self, cantidad):
        if cantidad > self.saldo:
            raise ValueError(f"{self.nombre} no tiene suficiente saldo para retirar {cantidad}.")
        self.saldo -= cantidad
        print(f"{self.nombre} ha retirado {cantidad}. Saldo actual: {self.saldo}")

    def transferir_dinero(self, otro_usuario, cantidad):
        if cantidad > otro_usuario.saldo:
            raise ValueError(f"{otro_usuario.nombre} no tiene suficiente saldo para transferir {cantidad}.")
        otro_usuario.saldo -= cantidad
        self.saldo += cantidad
        print(f"{self.nombre} ha recibido {cantidad} de {otro_usuario.nombre}. Saldo actual: {self.saldo}")

    def agregar_dinero(self, cantidad):
        self.saldo += cantidad
        print(f"{self.nombre} ha agregado {cantidad}. Saldo actual: {self.saldo}")

# %%
# 37.
# Crea una función llamada procesar_texto que procesa un texto según la opción especificada: contar_palabras , 
# reemplazar_palabras , eliminar_palabra . Estas opciones son otras funciones que tenemos que definir primero y llamar dentro
# de la función procesar_texto .
# Código a seguir:
#1. Crear una función contar_palabras para contar el número de veces que aparece cada palabra en el texto. Tiene
#que devolver un diccionario.
#2. Crear una función reemplazar_palabras para remplazar una palabra_original del texto por una palabra_nueva . Tiene
#que devolver el texto con el remplazo de palabras.
#3. Crear una función eliminar_palabra para eliminar una palabra del texto. Tiene que devolver el texto con la palabra
#eliminada.
#4. Crear la función procesar_texto que tome un texto, una opción(entre "contar", "reemplazar", "eliminar") y un
#número de argumentos variable según la opción indicada.
#Caso de uso:
#Comprueba el funcionamiento completo de la función procesar_text


def contar_palabras(texto):
    
    """Cuenta la frecuencia de cada palabra en un texto.

    Args:
        texto (str): texto a analizar

    Returns:
        frecuenias (dict): diccionario con palabras como claves y sus frecuencias como valores"""
    
    palabras = texto.split()
    frecuencias = {}
    
    for palabra in palabras:
        frecuencias[palabra] = frecuencias.get(palabra, 0) + 1
    
    return frecuencias

def reemplazar_palabras(texto, palabra_original, palabra_nueva):

    """Reemplaza todas las ocurrencias de una palabra en un texto por otra.

    Args:
        texto (str): texto a modificar
        palabra_original (str): palabra a reemplazar
        palabra_nueva (str): palabra que reemplazará a la original

    Returns:
        str: texto modificado con las palabras reemplazadas"""
    
    return texto.replace(palabra_original, palabra_nueva)

def eliminar_palabra(texto, palabra_a_eliminar):

    """Elimina una palabra específica de un texto.

    Args:
        texto (str): texto a modificar
        palabra_a_eliminar (str): palabra a eliminar

    Returns:
        str: texto modificado con la palabra eliminada"""
    
    return texto.replace(palabra_a_eliminar, "")




def procesar_texto(texto, opcion, *args):

    """Procesa un texto según la opción especificada: contar, reemplazar o eliminar palabras.

    Args:
        texto (str): texto a procesar
        opcion (str): opción de procesamiento ("contar", "reemplazar", "eliminar")
        *args: argumentos adicionales según la opción

    Returns:
        dict o str: dependiendo de la opción seleccionada. Diccionario de frecuencias para "contar", texto modificado para "reemplazar" y "eliminar"."""
    
    if opcion == "contar":
        return contar_palabras(texto)
    elif opcion == "reemplazar":
        if len(args) != 2:
            raise ValueError("Se requieren dos argumentos: palabra_original y palabra_nueva")
        return reemplazar_palabras(texto, args[0], args[1])
    elif opcion == "eliminar":
        if len(args) != 1:
            raise ValueError("Se requiere un argumento: palabra_a_eliminar")
        return eliminar_palabra(texto, args[0])
    else:
        raise ValueError("Opción no válida. Use 'contar', 'reemplazar' o 'eliminar'.")

# %%
import datetime

# %%
# 38. 
# Genera un programa que nos diga si es de noche, de día o tarde según la hora proporcionada por el usuario.

def dia_o_noche():
    
    """Función que determina si una hora está durante el día o la noche.

    Solicita al usuario una hora y verifica si cae en el horario de día (6:30-21:25)
    o en la noche."""

    hora_input = int(input("Ingrese hora -hh- de la hora elegida: "))
    min_input = int(input("Ingresde minutos -mm- de la hora elegida: "))
    seg_input = int(input ("Ingrese segundos -ss- de la hora elegida: "))

    hora_a_chequear = datetime.time(hora_input,min_input,seg_input)

    hora_inicio_dia=datetime.time(6,30,00)
    hora_inicio_noche=datetime.time(21,25,00)

    try:
        if hora_inicio_dia<hora_a_chequear<hora_inicio_noche:
            print(f"El horario {hora_a_chequear} es durante el día")
        else:
            print(f"El horario {hora_a_chequear} es durante la noche")
    except:
        print("Ingrese valores adecudados")


dia_o_noche()
# Out:
# El horario 22:10:12 es durante la noche

# %%
# 39.
# Escribe un programa que determine qué calificación en texto tiene un alumno en base a su calificación numérica.
#Las reglas de calificación son:
    #- 0 - 69 insuficiente
    #- 70 - 79 bien
    #- 80 - 89 muy bien
    #- 90 - 100 excelente

def calificac_texto():
    """Función que convierte una calificación numérica a texto.

    Solicita al usuario una calificación numérica y devuelve la descripción en texto:
    
    - 0-69: Insuficiente
    - 70-79: Bien
    - 80-89: Muy Bien
    - 90-100: Excelente"""

    try:

        calific_numerica = int(input("Ingrese la calificación numérica del alumno: "))

        calificacion_texto=""


        if 0<= calific_numerica < 70:

            calificac_texto = "Insuficiente"

        elif 70 <= calific_numerica < 80:

            calificac_texto = "Bien"

        elif 80<= calific_numerica < 90:

            calificac_texto = "Muy Bien"

        elif 90<= calific_numerica <= 100:

            calificac_texto = "Excelente"

        print(calificac_texto)  

    except ValueError:
        print("Ingrese una calificación numérica con valores adecuados")       
    

calificac_texto()
# Out:
# Muy Bien

# %%
# 40.
# Escribe una función que tome dos parámetros: figura (una cadena que puede ser "rectangulo" , "circulo" o 
# "triangulo" ) y datos (una tupla con los datos necesarios para calcular el área de la figura)

def calcular_area (figura, datosnecesarios):
    
    """Función que calcula el área de figuras geométricas.

    Calcula el área según el tipo de figura especificado usando los datos proporcionados.
    Soporta: rectángulo, círculo y triángulo.

    Args:
        figura (str): tipo de figura ("rectangulo", "circulo", "triangulo")
        datosnecesarios (tuple): datos necesarios para el cálculo
            - rectángulo/triángulo: (base, altura)
            - círculo: (radio,)

    Returns:
        float: área de la figura"""
    
    figura_minusc = figura.lower()

    if figura == "triangulo" and len(datosnecesarios) == 2:

        return datosnecesarios.index(0)*datosnecesarios.index(1)/2
    
    elif figura == "rectangulo" and len(datosnecesarios) == 2:

        return datosnecesarios.index(0)*datosnecesarios.index(1)
    
    elif figura == "circulo" and len(datosnecesarios) == 1:

        return 3.14*(datosnecesarios.index(0)**2)
    
    else:
        print ("Figura no corresponde o cantidad de datos erroneos")

# %%
# 41. En este ejercicio, se te pedirá que escribas un programa en Python que utilice condicionales para determinar el
# monto final de una compra en una tienda en línea, después de aplicar un descuento. El programa debe hacer lo
#siguiente:
# 1. Solicita al usuario que ingrese el precio original de un artículo.
# 2. Pregunta al usuario si tiene un cupón de descuento (respuesta sí o no).
# 3. Si el usuario responde que sí, solicita que ingrese el valor del cupón de descuento.
# 4. Aplica el descuento al precio original del artículo, siempre y cuando el valor del cupón sea válido (es decir, mayor
# a cero). Por ejemplo, descuento de 15€. 
# 5. Muestra el precio final de la compra, teniendo en cuenta el descuento aplicado o sin él. 
# 6. Recuerda utilizar estructuras de control de flujo como if, elif y else para llevar a cabo estas acciones en tu
# programa de Python

def monto_final():
        """Función que calcula el monto final de una compra con descuento.

    Solicita al usuario el precio original y pregunta si tiene un cupón de descuento.
    Aplica el descuento si es válido y muestra el precio final."""
    precio_original=float(input("Ingrese el precio original del artículo : "))

    cupon_si_no = input("¿Tienes un cupón de descuento? (SI/NO)").strip().lower()

    if cupon_si_no == "si":

        monto_descuento = float (input("Ingrese el valor del cupón de descuento"))

        if monto_descuento > 0:

            precio_final = precio_original - monto_descuento

            if precio_final < 0:

                precio_final = 0

            print("El cupón de descuento se ha aplicado correctamente")

        else:

            print("El valor del cupón de descuento debe ser mayor a cero")

    elif cupon_si_no == "no":

        precio_final = precio_original
        print ("No se ha aplicado ningún cupón de descuento")

    else:

        print ("Respuesta no válida, se aplicará el precio total sin descuento")

    print(f"El precio final de la compra es de {precio_final} euros")    



monto_final()
# Out:
# El cupón de descuento se ha aplicado correctamente
# El precio final de la compra es de 0 euros
